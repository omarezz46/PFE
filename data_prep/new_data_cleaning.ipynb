# %%
import pandas as pd

# %%
pd.read_csv('../data/extracted_papers/academic_nlp_papers.csv')
# Out:
#                                                  title  \
# 0    A survey of the usages of deep learning for na...
# 1         Deep learning in natural language processing
# 2        Deep learning for natural language processing
# 3    Deep learning for natural language processing:...
# 4    An introduction to deep learning in natural la...
# ..                                                 ...
# 295  GLUE: A multi-task benchmark and analysis plat...
# 296  A natural language-inspired multilabel video s...
# 297   Predicting process behaviour using deep learning
# 298               Deep learning in machine translation
# 299  Pro deep learning with TensorFlow 2.0: A mathe...
#
#                                               abstract  year  \
# 0    In the very recent past, the use of deep learn...  2020
# 1    deep learning, this book provides a comprehens...  2018
# 2    discussed on Deep Learning and Natural Languag...  2018
# ...
